# %%
import pandas as pd 
import numpy as np
import os

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
PATH = '/Users/kwonkyoungmi/workspaces/workspace_Python/Git_AtAiffel/datathon/data/MentalHealth'
data = pd.read_csv(os.path.join(PATH,'train.csv'))
data.columns
# Out:
# Index(['id', 'Name', 'Gender', 'Age', 'City',
#        'Working Professional or Student', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning

# %%
# 컬럼명 변경 딕셔너리 생성
new_column_names = {
    'Name': 'name',
    'Gender': 'gender',
    'Age': 'age',
    'City': 'city',
    'Working Professional or Student': 'occupation',
    'Profession': 'profession',
    'Academic Pressure': 'academic_pressure',
    'Work Pressure': 'work_pressure',
    'CGPA': 'cgpa',
    'Study Satisfaction': 'study_satisfaction',
    'Job Satisfaction': 'job_satisfaction',
    'Sleep Duration': 'sleep_duration',
    'Dietary Habits': 'dietary_habits',
    'Degree': 'degree',
    'Have you ever had suicidal thoughts ?': 'suicidal_thoughts', 
    'Work/Study Hours': 'work_study_hours',
    'Financial Stress': 'financial_stress',
    'Family History of Mental Illness': 'family_mh_history', # 'family_mh_history' (mh: mental health)
    'Depression': 'depression'
}

df = data.rename(columns=new_column_names)

# %%
# 중복값 확인
df.duplicated().sum() # 중복된 행이 있는지 확인
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140700 entries, 0 to 140699
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  140700 non-null  int64
#  1   name                140700 non-null  object
#  2   gender              140700 non-null  object
#  3   age                 140700 non-null  float64
#  4   city                140700 non-null  object
#  5   occupation          140700 non-null  object
#  6   profession          104070 non-null  object
#  7   academic_pressure   27897 non-null   float64
#  8   work_pressure       112782 non-null  float64
#  9   cgpa                27898 non-null   float64
#  10  study_satisfaction  27897 non-null   float64
#  11  job_satisfaction    112790 non-null  float64
#  12  sleep_duration      140700 non-null  object
#  13  dietary_habits      140696 non-null  object
#  14  degree              140698 non-null  object
#  15  suicidal_thoughts   140700 non-null  object
#  16  work_study_hours    140700 non-null  float64
#  17  financial_stress    140696 non-null  float64
#  18  family_mh_history   140700 non-null  object
#  19  depression          140700 non-null  int64
# dtypes: float64(8), int64(2), object(10)
# memory usage: 21.5+ MB

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# id                         0
# name                       0
# gender                     0
# age                        0
# city                       0
# occupation                 0
# profession             36630
# academic_pressure     112803
# work_pressure          27918
# cgpa                  112802
# study_satisfaction    112803
# job_satisfaction       27910
# sleep_duration             0
# dietary_habits             4
# degree                     2
# suicidal_thoughts          0
# work_study_hours           0
# financial_stress           4
# family_mh_history          0
# depression                 0
# dtype: int64

# %%
df.describe()
# Out:
#                   id            age  academic_pressure  work_pressure  \
# count  140700.000000  140700.000000       27897.000000  112782.000000
# mean    70349.500000      40.388621           3.142273       2.998998
# std     40616.735775      12.384099           1.380457       1.405771
# min         0.000000      18.000000           1.000000       1.000000
# 25%     35174.750000      29.000000           2.000000       2.000000
# 50%     70349.500000      42.000000           3.000000       3.000000
# 75%    105524.250000      51.000000           4.000000       4.000000
# max    140699.000000      60.000000           5.000000       5.000000
#
#                cgpa  study_satisfaction  job_satisfaction  work_study_hours  \
# count  27898.000000        27897.000000     112790.000000     140700.000000
# mean       7.658636            2.944940          2.974404          6.252679
# std        1.464466            1.360197          1.416078          3.853615
# min        5.030000            1.000000          1.000000          0.000000
# 25%        6.290000            2.000000          2.000000          3.000000
# 50%        7.770000            3.000000          3.000000          6.000000
# 75%        8.920000            4.000000          4.000000         10.000000
# max       10.000000            5.000000          5.000000         12.000000
#
#        financial_stress     depression
# count     140696.000000  140700.000000
# mean           2.988983       0.181713
# std            1.413633       0.385609
# min            1.000000       0.000000
# 25%            2.000000       0.000000
# 50%            3.000000       0.000000
# 75%            4.000000       0.000000
# max            5.000000       1.000000

# %% [markdown]
# #### gender

# %%
df['gender'].value_counts() # 원핫 인코딩 또는 male=0 female=1로 변환 필요
# Out:
# gender
# Male      77464
# Female    63236
# Name: count, dtype: int64

# %%
df['gender'] = df['gender'].replace({'Male' : 0, 'Female' : 1})
df['gender'].value_counts()
# Out:
# /var/folders/t3/2n0cthkn35z3g9p87_tw_5wm0000gn/T/ipykernel_1208/1577170353.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['gender'] = df['gender'].replace({'Male' : 0, 'Female' : 1})
# gender
# 0    77464
# 1    63236
# Name: count, dtype: int64

# %% [markdown]
# #### age

# %%
df['age'].value_counts() # 연령대별로 그룹화 필요
# Out:
# age
# 56.0    5246
# 49.0    5099
# 38.0    4564
# 53.0    4526
# 57.0    4395
# 47.0    4199
# 46.0    4080
# 54.0    3928
# 51.0    3927
# 18.0    3921
# 43.0    3856
# 59.0    3781
# 48.0    3695
# 45.0    3535
# 20.0    3515
# 50.0    3439
# 42.0    3393
# 24.0    3355
# 28.0    3338
# 39.0    3262
# 44.0    3217
# 33.0    3140
# 41.0    3140
# 29.0    3097
# 40.0    3094
# 58.0    2932
# 25.0    2931
# 23.0    2900
# 55.0    2846
# 35.0    2834
# 21.0    2742
# 37.0    2724
# 36.0    2703
# 19.0    2634
# 27.0    2613
# 52.0    2589
# 34.0    2578
# 31.0    2560
# 60.0    2501
# 26.0    2108
# 22.0    2066
# 30.0    1912
# 32.0    1785
# Name: count, dtype: int64

# %%
df['age'].max(),df['age'].min()
# Out:
# (60.0, 18.0)

# %%
# 연령대 그룹화
df['age_group'] = pd.cut(df['age'],
                        bins=[0, 18, 26, 36, 46, 56, 66, np.inf],
                        labels=['0-17', '18-25', '26-35', '36-45', '46-55', '56-65', '65+'],
                        right=False) # 왼쪽 경계값만 포함하고, 오른쪽 경계값은 포함 안함
df['age_group'].value_counts()
# Out:
# age_group
# 46-55    38328
# 36-45    33488
# 26-35    25965
# 18-25    24064
# 56-65    18855
# 0-17         0
# 65+          0
# Name: count, dtype: int64

# %% [markdown]
# #### occupation-profession

# %%
df[df.profession.isnull()].head()
# Out:
#     id       name  gender   age           city            occupation  \
# 2    2     Yuvraj       0  33.0  Visakhapatnam               Student
# 8    8  Aishwarya       1  24.0      Bangalore               Student
# 26  26     Aditya       0  31.0       Srinagar               Student
# 29  29    Kashish       1  19.0           Agra  Working Professional
# 30  30     Prisha       1  28.0       Varanasi               Student
#
#    profession  academic_pressure  work_pressure  cgpa  study_satisfaction  \
# 2         NaN                5.0            NaN  8.97                 2.0
# 8         NaN                2.0            NaN  5.90                 5.0
# 26        NaN                3.0            NaN  7.03                 5.0
# 29        NaN                NaN            1.0   NaN                 NaN
# 30        NaN                3.0            NaN  5.59                 2.0
#
#     job_satisfaction     sleep_duration dietary_habits    degree  \
# 2                NaN          5-6 hours        Healthy   B.Pharm
# 8                NaN          5-6 hours       Moderate       BSc
# 26               NaN  Less than 5 hours        Healthy        BA
# 29               5.0  More than 8 hours        Healthy  Class 12
# 30               NaN          7-8 hours       Moderate       BCA
#
#    suicidal_thoughts  work_study_hours  financial_stress family_mh_history  \
# 2                Yes               3.0               1.0                No
# 8                 No               3.0               2.0               Yes
# 26                No               9.0               1.0               Yes
# 29                No               5.0               2.0                No
# 30               Yes               4.0               5.0               Yes
#
#     depression age_group
# 2            1     26-35
# 8            0     18-25
# 26           0     26-35
# 29           0     18-25
# 30           1     26-35

# %%
#pd.set_option('display.max_colwidth', None)
df[df['occupation'] == 'Student']['profession'].unique().tolist()
# Out:
# [nan,
#  'Civil Engineer',
#  'Architect',
#  'UX/UI Designer',
#  'Digital Marketer',
#  'Content Writer',
#  'Educational Consultant',
#  'Teacher',
#  'Student',
#  'Manager',
#  'Chef',
#  'Doctor',
#  'Lawyer',
#  'Entrepreneur',
#  'Pharmacist']

# %%
black_list = df[df['occupation'] == 'Student']['profession'].dropna().unique().tolist()

df.loc[(df['occupation'] == 'Student') & 
         (df['profession'].isin(black_list))]
# Out:
#             id     name  gender   age           city occupation  \
# 609        609    Anand       0  21.0      Ahmedabad    Student
# 2105      2105   Shreya       1  31.0       Vadodara    Student
# 9483      9483    Vidya       1  32.0         Kalyan    Student
# 11470    11470   Anjali       1  28.0      Ahmedabad    Student
# 12425    12425    Rupak       0  25.0         Kalyan    Student
# 16196    16196    Ivaan       0  33.0         Jaipur    Student
# 16959    16959    Vidhi       1  24.0         Mumbai    Student
# 18291    18291   Ritvik       0  32.0           Agra    Student
# 19226    19226    Rupak       0  31.0         Rajkot    Student
# 20049    20049   Himani       1  24.0        Kolkata    Student
# 20296    20296    Ayaan       0  32.0           Agra    Student
# 25193    25193   Tushar       0  24.0         Kalyan    Student
# 43035    43035    Rupak       0  23.0          Patna    Student
# 61219    61219    Vibha       1  23.0         Kalyan    Student
# 62410    62410  Anushka       1  34.0      Ghaziabad    Student
# 72541    72541  Nandini       1  28.0      Hyderabad    Student
# 78083    78083    Vivan       0  32.0         Meerut    Student
# 81442    81442    Rajat       0  23.0         Kanpur    Student
# 88879    88879  Kashish       1  29.0           Agra    Student
# 89052    89052     Veda       1  29.0         Meerut    Student
# 92226    92226   Yogesh       0  26.0         Bhopal    Student
# 104123  104123    Aarav       0  28.0       Ludhiana    Student
# 105237  105237     Esha       1  21.0        Chennai    Student
# 105595  105595    Rishi       0  28.0         Jaipur    Student
# 111939  111939   Vikram       0  24.0      Bangalore    Student
# 121474  121474   Aakash       0  27.0         Kalyan    Student
# 123259  123259    Arjun       0  23.0         Kanpur    Student
# 126162  126162  Kashish       1  30.0         Nagpur    Student
# 127070  127070   Armaan       0  32.0         Meerut    Student
# 127637  127637    Vidya       1  25.0          Delhi    Student
# 129499  129499    Aditi       1  21.0         Kalyan    Student
# 132550  132550     Ansh       0  25.0  Visakhapatnam    Student
# 136642  136642   Pranav       0  29.0       Ludhiana    Student
# 140522  140522    Kriti       1  22.0    Vasai-Virar    Student
#
#                     profession  academic_pressure  work_pressure  cgpa  \
# 609             Civil Engineer                5.0            NaN  7.83
# 2105                 Architect                5.0            NaN  6.95
# 9483            UX/UI Designer                3.0            NaN  9.60
# 11470         Digital Marketer                5.0            NaN  9.72
# 12425           Content Writer                5.0            NaN  8.50
# 16196                Architect                2.0            NaN  7.13
# 16959                Architect                3.0            NaN  8.89
# 18291   Educational Consultant                3.0            NaN  5.74
# 19226                  Teacher                3.0            NaN  7.48
# 20049                  Student                1.0            NaN  7.32
# 20296                  Student                2.0            NaN  8.13
# 25193                  Teacher                4.0            NaN  9.66
# 43035                  Manager                3.0            NaN  8.62
# 61219                     Chef                3.0            NaN  9.91
# 62410           Content Writer                5.0            NaN  6.83
# 72541                Architect                3.0            NaN  6.99
# 78083                   Doctor                5.0            NaN  9.70
# 81442                   Lawyer                4.0            NaN  6.88
# 88879                     Chef                2.0            NaN  6.86
# 89052                   Doctor                3.0            NaN  6.35
# 92226                Architect                4.0            NaN  7.28
# 104123        Digital Marketer                1.0            NaN  9.41
# 105237            Entrepreneur                3.0            NaN  8.17
# 105595                 Teacher                3.0            NaN  5.82
# 111939               Architect                5.0            NaN  7.09
# 121474                 Teacher                3.0            NaN  5.89
# 123259                 Teacher                3.0            NaN  5.59
# 126162                 Student                5.0            NaN  7.24
# 127070              Pharmacist                4.0            NaN  8.54
# 127637               Architect                5.0            NaN  8.98
# 129499        Digital Marketer                5.0            NaN  6.91
# 132550                 Teacher                5.0            NaN  7.25
# 136642              Pharmacist                4.0            NaN  5.77
# 140522               Architect                3.0            NaN  9.13
#
#         study_satisfaction  job_satisfaction     sleep_duration  \
# 609                    1.0               NaN          5-6 hours
# 2105                   3.0               NaN  Less than 5 hours
# 9483                   2.0               NaN          7-8 hours
# 11470                  3.0               NaN  More than 8 hours
# 12425                  2.0               NaN          5-6 hours
# 16196                  4.0               NaN  More than 8 hours
# 16959                  5.0               NaN  More than 8 hours
# 18291                  4.0               NaN          7-8 hours
# 19226                  5.0               NaN          5-6 hours
# 20049                  4.0               NaN  More than 8 hours
# 20296                  5.0               NaN  More than 8 hours
# 25193                  5.0               NaN          7-8 hours
# 43035                  2.0               NaN  More than 8 hours
# 61219                  4.0               NaN          7-8 hours
# 62410                  4.0               NaN          7-8 hours
# 72541                  3.0               NaN          5-6 hours
# 78083                  3.0               NaN  Less than 5 hours
# 81442                  1.0               NaN  More than 8 hours
# 88879                  3.0               NaN          7-8 hours
# 89052                  3.0               NaN  Less than 5 hours
# 92226                  3.0               NaN  More than 8 hours
# 104123                 5.0               NaN          5-6 hours
# 105237                 5.0               NaN  Less than 5 hours
# 105595                 4.0               NaN          5-6 hours
# 111939                 4.0               NaN  Less than 5 hours
# 121474                 3.0               NaN  Less than 5 hours
# 123259                 1.0               NaN  More than 8 hours
# 126162                 1.0               NaN  Less than 5 hours
# 127070                 1.0               NaN          7-8 hours
# 127637                 3.0               NaN  More than 8 hours
# 129499                 4.0               NaN  Less than 5 hours
# 132550                 1.0               NaN          7-8 hours
# 136642                 4.0               NaN  More than 8 hours
# 140522                 4.0               NaN          7-8 hours
#
#        dietary_habits   degree suicidal_thoughts  work_study_hours  \
# 609           Healthy      MSc               Yes              11.0
# 2105         Moderate      BSc                No               8.0
# 9483         Moderate      PhD               Yes               5.0
# 11470         Healthy       MA               Yes              10.0
# 12425        Moderate     B.Ed               Yes               0.0
# 16196        Moderate      MSc                No               2.0
# 16959       Unhealthy      MSc               Yes               3.0
# 18291         Healthy     B.Ed               Yes               3.0
# 19226       Unhealthy       MD               Yes              12.0
# 20049        Moderate       MA               Yes               8.0
# 20296       Unhealthy     B.Ed                No              11.0
# 25193        Moderate       BE               Yes              12.0
# 43035         Healthy      BHM                No               9.0
# 61219         Healthy      BHM               Yes              10.0
# 62410        Moderate       MA               Yes               5.0
# 72541        Moderate      BSc               Yes              10.0
# 78083         Healthy  M.Pharm               Yes               3.0
# 81442       Unhealthy      LLM               Yes               2.0
# 88879        Moderate      BHM               Yes              12.0
# 89052         Healthy       MD                No              12.0
# 92226         Healthy      BSc                No              12.0
# 104123        Healthy       BA               Yes               5.0
# 105237       Moderate      MCA               Yes               4.0
# 105595       Moderate       MD               Yes               5.0
# 111939      Unhealthy      BBA               Yes               1.0
# 121474      Unhealthy      MSc               Yes               2.0
# 123259        Healthy      BCA               Yes              11.0
# 126162      Unhealthy       MD               Yes               3.0
# 127070      Unhealthy     MBBS               Yes               2.0
# 127637        Healthy   B.Arch               Yes               5.0
# 129499       Moderate    M.Com                No              10.0
# 132550      Unhealthy     B.Ed               Yes               1.0
# 136642        Healthy  B.Pharm               Yes               4.0
# 140522      Unhealthy      MCA               Yes               4.0
#
#         financial_stress family_mh_history  depression age_group
# 609                  3.0               Yes           1     18-25
# 2105                 1.0               Yes           1     26-35
# 9483                 3.0                No           1     26-35
# 11470                5.0               Yes           1     26-35
# 12425                2.0               Yes           1     18-25
# 16196                5.0               Yes           1     26-35
# 16959                5.0               Yes           1     18-25
# 18291                5.0               Yes           1     26-35
# 19226                2.0               Yes           1     26-35
# 20049                3.0               Yes           0     18-25
# 20296                1.0                No           0     26-35
# 25193                3.0                No           1     18-25
# 43035                5.0                No           1     18-25
# 61219                3.0                No           1     18-25
# 62410                5.0                No           1     26-35
# 72541                5.0               Yes           1     26-35
# 78083                4.0                No           1     26-35
# 81442                4.0                No           1     18-25
# 88879                4.0               Yes           1     26-35
# 89052                1.0                No           1     26-35
# 92226                4.0               Yes           0     26-35
# 104123               3.0               Yes           0     26-35
# 105237               3.0                No           1     18-25
# 105595               1.0                No           0     26-35
# 111939               3.0               Yes           1     18-25
# 121474               5.0                No           1     26-35
# 123259               4.0               Yes           1     18-25
# 126162               3.0               Yes           0     26-35
# 127070               5.0               Yes           1     26-35
# 127637               5.0                No           1     18-25
# 129499               5.0                No           1     18-25
# 132550               1.0               Yes           1     18-25
# 136642               2.0                No           1     26-35
# 140522               1.0               Yes           1     18-25

# %%
df_1 = df.copy()

df_1['occupation'] = df_1['occupation'].replace({'Working Professional' : 'professional', 'Student' : 'student'})
df_1['occupation'].value_counts()
# Out:
# occupation
# professional    112799
# student          27901
# Name: count, dtype: int64

# %%
# occupation이 'student'인 경우 profession에 값을 모두 'student'로 변경
black_list = df_1[df_1['occupation'] == 'student']['profession'].unique().tolist()

df_1.loc[(df_1['occupation'] == 'student') & 
         (df_1['profession'].isin(black_list)),
         'profession'] = 'student'

df_1[df_1['occupation'] == 'student'].groupby('occupation')['profession'].unique().to_list()
# Out:
# [array(['student'], dtype=object)]

# %%
df_1[df_1['occupation'] == 'professional']['profession'].unique().tolist()
#df_1['profession'].unique()
# Out:
# ['Chef',
#  'Teacher',
#  'Business Analyst',
#  'Finanancial Analyst',
#  'Chemist',
#  'Electrician',
#  'Software Engineer',
#  'Data Scientist',
#  'Plumber',
#  'Marketing Manager',
#  'Accountant',
#  'Entrepreneur',
#  'HR Manager',
#  'UX/UI Designer',
#  'Content Writer',
#  nan,
#  'Educational Consultant',
#  'Civil Engineer',
#  'Manager',
#  'Pharmacist',
#  'Financial Analyst',
#  'Architect',
#  'Mechanical Engineer',
#  'Customer Support',
#  'Consultant',
#  'Judge',
#  'Researcher',
#  'Pilot',
#  'Graphic Designer',
#  'Travel Consultant',
#  'Digital Marketer',
#  'Lawyer',
#  'Research Analyst',
#  'Sales Executive',
#  'Doctor',
#  'Unemployed',
#  'Investment Banker',
#  'Family Consultant',
#  'B.Com',
#  'BE',
#  'Student',
#  'Yogesh',
#  'Dev',
#  'MBA',
#  'LLM',
#  'BCA',
#  'Academic',
#  'Profession',
#  'FamilyVirar',
#  'City Manager',
#  'BBA',
#  'Medical Doctor',
#  'Working Professional',
#  'MBBS',
#  'Patna',
#  'Unveil',
#  'B.Ed',
#  'Nagpur',
#  'Moderate',
#  'M.Ed',
#  'Analyst',
#  'Pranav',
#  'Visakhapatnam',
#  'PhD',
#  'Yuvraj']

# %%
df_1['profession'] = df_1['profession'].replace('Finanancial Analyst', 'Financial Analyst')

valid_professions = [
    'CHEF', 'TEACHER', 'BUSINESS ANALYST', 'FINANCIAL ANALYST', 'CHEMIST',
    'ELECTRICIAN', 'SOFTWARE ENGINEER', 'DATA SCIENTIST', 'PLUMBER',
    'MARKETING MANAGER', 'ACCOUNTANT', 'ENTREPRENEUR', 'HR MANAGER',
    'UX/UI DESIGNER', 'CONTENT WRITER', 'EDUCATIONAL CONSULTANT',
    'CIVIL ENGINEER', 'MANAGER', 'PHARMACIST', 'ARCHITECT',
    'MECHANICAL ENGINEER', 'CUSTOMER SUPPORT', 'CONSULTANT', 'JUDGE',
    'RESEARCHER', 'PILOT', 'GRAPHIC DESIGNER', 'TRAVEL CONSULTANT',
    'DIGITAL MARKETER', 'LAWYER', 'RESEARCH ANALYST', 'SALES EXECUTIVE',
    'DOCTOR', 'UNEMPLOYED', 'INVESTMENT BANKER', 'FAMILY CONSULTANT',
    'ACADEMIC', 'CITY MANAGER', 'MEDICAL DOCTOR', 'ANALYST', 'STUDENT', 'WORKING PROFESSIONAL'
    # 'STUDENT'와 'WORKING PROFESSIONAL'은 'occupation' 컬럼에 속해야 하므로 우선 살려 두고 확인하여 NaN 처리 또는 occupation 컬럼으로 이동
    # 학위 (B.Com, BE, MBA 등), 이름 (Yogesh, Dev 등), 도시 (Patna, Nagpur 등),
    # 그 외 의미 없는 값 (Profession, FamilyVirar, Unveil, Moderate) 등은 모두 제외
]

incorrect_profession_values = [
    'B.Com','BE','MBA','LLM','BCA','BBA','MBBS','B.Ed','M.Ed','PhD',# 학위/학력 (Degree 컬럼에 속해야 할 값)
    'Yogesh','Dev','Pranav','Yuvraj', # 사람 이름 (Name 컬럼에 속해야 할 값)
    'Patna','Nagpur','Visakhapatnam', # 도시 이름 (City 컬럼에 속해야 할 값)
    'Profession',        # 컬럼 이름 자체
    'FamilyVirar',       # 불분명한 값, 직업으로 보이지 않음
    'Unveil',            # 불분명한 값
    'Moderate',          # 압력 수준 등을 나타내는 값일 가능성 높음
    #'Working Professional', # 'occupation' 컬럼에 속해야 할 값 => 우선 살려 두고 확인
    #'Student',           # 'occupation' 컬럼에 속해야 할 값 => 우선 살려 두고 확인
    np.nan               # 결측값 (오류는 아니지만 처리 필요)
]

df_2 = df_1.copy()
df_2['profession'] = df_2['profession'].fillna('').astype(str).str.upper()
df_2.loc[~df_2['profession'].isin(valid_professions), 'profession'] = np.nan


df_2['profession'] = df_2['profession'].astype(str).str.lower().replace('nan',np.nan)
df_2[df_2['occupation'] == 'professional']['profession'].unique().tolist()
# Out:
# ['chef',
#  'teacher',
#  'business analyst',
#  'financial analyst',
#  'chemist',
#  'electrician',
#  'software engineer',
#  'data scientist',
#  'plumber',
#  'marketing manager',
#  'accountant',
#  'entrepreneur',
#  'hr manager',
#  'ux/ui designer',
#  'content writer',
#  nan,
#  'educational consultant',
#  'civil engineer',
#  'manager',
#  'pharmacist',
#  'architect',
#  'mechanical engineer',
#  'customer support',
#  'consultant',
#  'judge',
#  'researcher',
#  'pilot',
#  'graphic designer',
#  'travel consultant',
#  'digital marketer',
#  'lawyer',
#  'research analyst',
#  'sales executive',
#  'doctor',
#  'unemployed',
#  'investment banker',
#  'family consultant',
#  'student',
#  'academic',
#  'city manager',
#  'medical doctor',
#  'working professional',
#  'analyst']

# %%
df_2[df_2['profession'] == 'working professional'] # 삭제 할 것
df_3 = df_2[~(df_2['profession'] == 'working professional')]

# %%
# profession을 'student'으로 작성 후 아카데미 pressure를 work_pressure로 작성한 경우 우선 살려 둠 => 추후 profession과 occupation을 통합할 예정 
df_3.loc[(df_3['occupation'] == 'professional') & (df_3['profession'] == 'student')]
# Out:
#           id    name  gender   age       city    occupation profession  \
# 11509  11509  Prisha       1  22.0      Thane  professional    student
# 25447  25447  Gaurav       0  60.0       Pune  professional    student
# 73447  73447  Harsha       0  35.0  Ahmedabad  professional    student
# 88617  88617   Ayush       0  29.0   Srinagar  professional    student
#
#        academic_pressure  work_pressure  cgpa  study_satisfaction  \
# 11509                NaN            3.0   NaN                 NaN
# 25447                NaN            3.0   NaN                 NaN
# 73447                NaN            4.0   NaN                 NaN
# 88617                NaN            4.0   NaN                 NaN
#
#        job_satisfaction     sleep_duration dietary_habits   degree  \
# 11509               2.0          7-8 hours       Moderate    B.Com
# 25447               2.0          5-6 hours      Unhealthy  M.Pharm
# 73447               2.0  Less than 5 hours       Moderate      BSc
# 88617               2.0          5-6 hours       Moderate       BE
#
#       suicidal_thoughts  work_study_hours  financial_stress family_mh_history  \
# 11509               Yes               5.0               2.0                No
# 25447                No               8.0               1.0               Yes
# 73447                No               1.0               3.0               Yes
# 88617                No              10.0               1.0               Yes
#
#        depression age_group
# 11509           0     18-25
# 25447           0     56-65
# 73447           0     26-35
# 88617           0     26-35

# %%
df_3[df_3['occupation'] == 'student']['profession'].unique().tolist()
# Out:
# ['student']

# %%
df_3[df_3['occupation'] != 'student']['profession'].unique().tolist()
# Out:
# ['chef',
#  'teacher',
#  'business analyst',
#  'financial analyst',
#  'chemist',
#  'electrician',
#  'software engineer',
#  'data scientist',
#  'plumber',
#  'marketing manager',
#  'accountant',
#  'entrepreneur',
#  'hr manager',
#  'ux/ui designer',
#  'content writer',
#  nan,
#  'educational consultant',
#  'civil engineer',
#  'manager',
#  'pharmacist',
#  'architect',
#  'mechanical engineer',
#  'customer support',
#  'consultant',
#  'judge',
#  'researcher',
#  'pilot',
#  'graphic designer',
#  'travel consultant',
#  'digital marketer',
#  'lawyer',
#  'research analyst',
#  'sales executive',
#  'doctor',
#  'unemployed',
#  'investment banker',
#  'family consultant',
#  'student',
#  'academic',
#  'city manager',
#  'medical doctor',
#  'analyst']

# %%
df_3['occupation'].isnull().sum()
# Out:
# 0

# %%
# df_3['profession'].isnull().groupby(df_3['city']).sum().sort_values(ascending=False)
# 직업이 없는 경우 'unemployed'로 변경
df_3.loc[df_3['profession'].isnull(), 'profession'] = 'unemployed'
# 직업이 없는 경우 'unemployed'로 변경 후 다시 확인
df_3['profession'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### pressure & satisfaction
# `academic_pressure`와 `work_pressure` 통합하기 => `study_work_pressure`
# `study_satisfaction`와 `job satisfaction` 통합하기 => `study_work_satistaction`

# %%
# academic_pressure와 work_pressure 동시에 들어간 컬럼 있는지 확인
df_3[df_3['academic_pressure'].notna() & df_3['work_pressure'].notna()] # 없음 확인
# Out:
# Empty DataFrame
# Columns: [id, name, gender, age, city, occupation, profession, academic_pressure, work_pressure, cgpa, study_satisfaction, job_satisfaction, sleep_duration, dietary_habits, degree, suicidal_thoughts, work_study_hours, financial_stress, family_mh_history, depression, age_group]
# Index: []

# %%
# study_satisfaction와 job_satisfaction 동시에 들어간 컬럼 있는지 확인
df_3[df_3['study_satisfaction'].notna() & df_3['job_satisfaction'].notna()] # 2개의 레코드 => 삭제

df_4 = df_3[~(df_3['study_satisfaction'].notna() & df_3['job_satisfaction'].notna())]
df_4[df_4['study_satisfaction'].notna() & df_4['job_satisfaction'].notna()] # 삭제 완료 확인
# Out:
# Empty DataFrame
# Columns: [id, name, gender, age, city, occupation, profession, academic_pressure, work_pressure, cgpa, study_satisfaction, job_satisfaction, sleep_duration, dietary_habits, degree, suicidal_thoughts, work_study_hours, financial_stress, family_mh_history, depression, age_group]
# Index: []

# %%
# 'academic_pressure','work_pressure','study_satisfaction','job_satisfaction'
cols_to_fill_zero = [
    'academic_pressure',
    'work_pressure',
    'study_satisfaction',
    'job_satisfaction'
]

df_4[cols_to_fill_zero] = df_4[cols_to_fill_zero].fillna(0)
df_4[cols_to_fill_zero].isna().sum()
# Out:
# /var/folders/t3/2n0cthkn35z3g9p87_tw_5wm0000gn/T/ipykernel_1208/2448173090.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4[cols_to_fill_zero] = df_4[cols_to_fill_zero].fillna(0)
# academic_pressure     0
# work_pressure         0
# study_satisfaction    0
# job_satisfaction      0
# dtype: int64

# %%
df_4[df_4['job_satisfaction'].isna()]
# Out:
# Empty DataFrame
# Columns: [id, name, gender, age, city, occupation, profession, academic_pressure, work_pressure, cgpa, study_satisfaction, job_satisfaction, sleep_duration, dietary_habits, degree, suicidal_thoughts, work_study_hours, financial_stress, family_mh_history, depression, age_group, study_work_pressure, study_work_satisfaction]
# Index: []

# %%
df_4['work_study_pressure'] = df_4['academic_pressure'] + df_4['work_pressure']
df_4['work_study_satisfaction'] = df_4['study_satisfaction'] + df_4['job_satisfaction']
df_4['work_study_pressure'].isna().sum(), df_4['study_work_satisfaction'].isna().sum()
# Out:
# /var/folders/t3/2n0cthkn35z3g9p87_tw_5wm0000gn/T/ipykernel_1208/2282565149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4['work_study_pressure'] = df_4['academic_pressure'] + df_4['work_pressure']
# /var/folders/t3/2n0cthkn35z3g9p87_tw_5wm0000gn/T/ipykernel_1208/2282565149.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4['work_study_satisfaction'] = df_4['study_satisfaction'] + df_4['job_satisfaction']
# (0, 0)

# %%
df_5 = df_4[['id', 'name', 'gender', 'age','age_group','city', 'profession', 'cgpa','degree',
       'work_study_pressure','work_study_satisfaction', 'financial_stress',
       'sleep_duration','dietary_habits', 'work_study_hours',
       'family_mh_history','suicidal_thoughts','depression'
       ]]

# %%
df_5.head()
# Out:
#    id      name  gender   age age_group           city        profession  \
# 0   0  Aaradhya       1  49.0     46-55       Ludhiana              chef
# 1   1     Vivan       0  26.0     26-35       Varanasi           teacher
# 2   2    Yuvraj       0  33.0     26-35  Visakhapatnam           student
# 3   3    Yuvraj       0  22.0     18-25         Mumbai           teacher
# 4   4      Rhea       1  30.0     26-35         Kanpur  business analyst
#
#    cgpa   degree  work_study_pressure  work_study_satisfaction  \
# 0   NaN      BHM                  5.0                      2.0
# 1   NaN      LLB                  4.0                      3.0
# 2  8.97  B.Pharm                  5.0                      2.0
# 3   NaN      BBA                  5.0                      1.0
# 4   NaN      BBA                  1.0                      1.0
#
#    financial_stress     sleep_duration dietary_habits  work_study_hours  \
# 0               2.0  More than 8 hours        Healthy               1.0
# 1               3.0  Less than 5 hours      Unhealthy               7.0
# 2               1.0          5-6 hours        Healthy               3.0
# 3               1.0  Less than 5 hours       Moderate              10.0
# 4               4.0          5-6 hours      Unhealthy               9.0
#
#   family_mh_history suicidal_thoughts  depression
# 0                No                No           0
# 1                No               Yes           1
# 2                No               Yes           1
# 3               Yes               Yes           1
# 4               Yes               Yes           0

# %% [markdown]
# #### CGPA

# %%
df_5.isna().sum()
# Out:
# id                              0
# name                            0
# gender                          0
# age                             0
# age_group                       0
# city                            0
# profession                      0
# cgpa                       112801
# degree                          2
# work_study_pressure             0
# work_study_satisfaction         0
# financial_stress                4
# sleep_duration                  0
# dietary_habits                  4
# work_study_hours                0
# family_mh_history               0
# suicidal_thoughts               0
# depression                      0
# dtype: int64

# %%
len(df_5[~(df_5['profession'] == 'student')]['cgpa']) # 112794
df_5[~(df_5['profession'] == 'student')]['cgpa'].isna().sum() #112784
# Out:
# 112788

# %%
df_5[~(df_5['profession'] == 'student') & df_5['cgpa'].notna()]

# student가 아닌 경우, CGPA가 없어야 함 ; 있으면 이상치 간주 => NaN 처리
df_5.loc[~(df_5['profession'] == 'student') & df_5['cgpa'].notna(), 'cgpa'] = np.nan
df_5[~(df_5['profession'] == 'student') & df_5['cgpa'].notna()] # 이상치 확인 완료
# Out:
# Empty DataFrame
# Columns: [id, name, gender, age, age_group, city, profession, cgpa, degree, work_study_pressure, work_study_satisfaction, financial_stress, sleep_duration, dietary_habits, work_study_hours, family_mh_history, suicidal_thoughts, depression]
# Index: []

# %%
df_5[(df_5['profession'] == 'student') & df_5['cgpa'].isna()]['city'].value_counts()
"""
# student인 경우, CGPA가 있어야 함 ; 없으면 이상치 간주 => 삭제 (지역별 결측치가 적어서 삭제하기로 결정 )
Ahmedabad    3
Vadodara     2
Pune         2
Thane        1
Chennai      1
Lucknow      1
Srinagar     1
Rajkot       1
Meerut       1
"""

# student인 경우, CGPA가 없는 경우 삭제
df_6 = df_5[~((df_5['profession'] == 'student') & df_5['cgpa'].isna())]

# %%
df_6[df_6['profession'] == 'student']['cgpa'].isna().sum() # 0 확인
df_6[df_6['profession'] != 'student']['cgpa'].isna().sum() == len(df_6[df_6['profession'] != 'student'])
# Out:
# True

# %%
len(df_6['profession'])
# Out:
# 140684

# %%
# NaN 처리 => 0으로 변경
df_6['cgpa'] = df_6['cgpa'].fillna(0)
df_6['cgpa'].isna().sum() # 0
# Out:
# /var/folders/t3/2n0cthkn35z3g9p87_tw_5wm0000gn/T/ipykernel_1208/3081086637.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6['cgpa'] = df_6['cgpa'].fillna(0)
# 0

# %% [markdown]
# #### sleep duration

# %%
df_6['sleep_duration'].value_counts()
# Out:
# sleep_duration
# Less than 5 hours    38777
# 7-8 hours            36964
# More than 8 hours    32725
# 5-6 hours            32139
# 3-4 hours               12
# 6-7 hours                8
# 4-5 hours                7
# 4-6 hours                5
# 2-3 hours                5
# 6-8 hours                4
# No                       4
# 1-6 hours                4
# 10-11 hours              2
# 9-11 hours               2
# 8-9 hours                2
# Sleep_Duration           2
# Unhealthy                2
# 45                       2
# 40-45 hours              1
# 1-2 hours                1
# 1-3 hours                1
# 9-6 hours                1
# 55-66 hours              1
# Moderate                 1
# 35-36 hours              1
# 8 hours                  1
# 10-6 hours               1
# Indore                   1
# than 5 hours             1
# 49 hours                 1
# Work_Study_Hours         1
# 3-6 hours                1
# 45-48 hours              1
# 9-5                      1
# Pune                     1
# 9-5 hours                1
# Name: count, dtype: int64

# %%
df_7 = df_6.copy()
df_7['sleep_duration'] = df_7['sleep_duration'].replace({'Less than 5 hours': 'insufficient', 
                                                         '5-6 hours': 'insufficient', 
                                                         '7-8 hours': 'optimal', 
                                                         'More than 8 hours': 'excessive'})
df_7['sleep_duration'].value_counts()
# Out:
# sleep_duration
# insufficient        70916
# optimal             36964
# excessive           32725
# 3-4 hours              12
# 6-7 hours               8
# 4-5 hours               7
# 4-6 hours               5
# 2-3 hours               5
# 6-8 hours               4
# No                      4
# 1-6 hours               4
# 10-11 hours             2
# 9-11 hours              2
# 8-9 hours               2
# Sleep_Duration          2
# Unhealthy               2
# 45                      2
# 40-45 hours             1
# 1-2 hours               1
# 1-3 hours               1
# 9-6 hours               1
# 55-66 hours             1
# Moderate                1
# 35-36 hours             1
# 8 hours                 1
# 10-6 hours              1
# Indore                  1
# than 5 hours            1
# 49 hours                1
# Work_Study_Hours        1
# 3-6 hours               1
# 45-48 hours             1
# 9-5                     1
# Pune                    1
# 9-5 hours               1
# Name: count, dtype: int64

# %%
# sleep_duration value_counts()가 5개 이하 인 데이터 삭제

# 5개 이하인 sleep_duration
a = df_7['sleep_duration'].value_counts()[df_7['sleep_duration'].value_counts() <= 12].index

df_7 = df_7[~df_7['sleep_duration'].isin(a)]
df_7['sleep_duration'].value_counts()
# Out:
# sleep_duration
# insufficient    70916
# optimal         36964
# excessive       32725
# Name: count, dtype: int64

# %% [markdown]
# #### Dietary_habits

# %%
df_7['dietary_habits'].value_counts()

# dietary_habits value_counts()가 5개 이하 인 데이터 삭제
# 5개 이하인 dietary_habits

b = df_7['dietary_habits'].value_counts()[df_7['dietary_habits'].value_counts() <= 5].index
df_7 = df_7[~(df_7['dietary_habits'].isin(b))]
df_7['dietary_habits'].value_counts()
# Out:
# dietary_habits
# Moderate     49661
# Unhealthy    46196
# Healthy      44721
# Name: count, dtype: int64

# %%
df_7[df_7['dietary_habits'].isna()]
# Out:
#           id         name  gender   age age_group       city      profession  \
# 59350  59350       Tanmay       0  34.0     26-35       Agra         student
# 64565  64565         Anvi       1  23.0     18-25  Bangalore         student
# 69581  69581       Vikram       0  48.0     46-55  Hyderabad      consultant
# 76436  76436  Raghavendra       0  37.0     36-45     Nashik  civil engineer
#
#        cgpa   degree  work_study_pressure  work_study_satisfaction  \
# 59350  9.04   B.Tech                  5.0                      1.0
# 64565  6.91  M.Pharm                  2.0                      5.0
# 69581  0.00      MBA                  3.0                      2.0
# 76436  0.00       ME                  3.0                      3.0
#
#        financial_stress sleep_duration dietary_habits  work_study_hours  \
# 59350               5.0      excessive            NaN               4.0
# 64565               3.0   insufficient            NaN               6.0
# 69581               4.0   insufficient            NaN               5.0
# 76436               1.0        optimal            NaN              11.0
#
#       family_mh_history suicidal_thoughts  depression
# 59350               Yes               Yes           1
# 64565                No                No           1
# 69581                No                No           0
# 76436                No                No           0

# %%
df_7 = df_7.dropna(subset=['dietary_habits'])
df_7['dietary_habits'].isna().sum() # 0 확인
# Out:
# 0

# %% [markdown]
# #### degree

# %%
df_7['degree'].unique().tolist()
# Out:
# ['BHM',
#  'LLB',
#  'B.Pharm',
#  'BBA',
#  'MCA',
#  'MD',
#  'BSc',
#  'ME',
#  'B.Arch',
#  'BCA',
#  'BE',
#  'MA',
#  'B.Ed',
#  'B.Com',
#  'MBA',
#  'M.Com',
#  'MHM',
#  'BA',
#  'Class 12',
#  'M.Tech',
#  'PhD',
#  'M.Ed',
#  'MSc',
#  'B.Tech',
#  'LLM',
#  'MBBS',
#  'M.Pharm',
#  'UX/UI Designer',
#  'MPA',
#  'BH',
#  'Nalini',
#  'BEd',
#  'B.Sc',
#  'Veda',
#  'Bhopal',
#  'S.Tech',
#  'Degree',
#  '20',
#  'Class 11',
#  'H_Pharm',
#  'M',
#  'P.Com',
#  'BPharm',
#  'Business Analyst',
#  'M.Arch',
#  'LL.Com',
#  'Data Scientist',
#  'MPharm',
#  'L.Ed',
#  'P.Pharm',
#  'Kalyan',
#  'Unite',
#  'BArch',
#  'HR Manager',
#  'Badhya',
#  'S.Pharm',
#  'LLBA',
#  'Vrinda',
#  'M. Business Analyst',
#  'Bhavesh',
#  '0',
#  'LLCom',
#  '29',
#  'MTech',
#  'Vivaan',
#  'BPA',
#  'Plumber',
#  '5.61',
#  'Brit',
#  'B.03',
#  'Ritik',
#  '5.56',
#  'MEd',
#  'B',
#  'B BA',
#  '7.06',
#  'B.B.Arch',
#  'ACA',
#  'Brithika',
#  'CGPA',
#  '24',
#  'M_Tech',
#  'Pihu',
#  'BB',
#  'Jhanvi',
#  'LLTech',
#  'Aarav',
#  'Entrepreneur',
#  '8.56',
#  'LHM',
#  'Lata',
#  'S.Arch',
#  'Marsh',
#  'HCA',
#  '5.88',
#  'B.Student',
#  'LL B.Ed',
#  'M.S',
#  'Navya',
#  'Mahika',
#  nan,
#  'K.Ed',
#  'B.3.79',
#  'Mthanya',
#  'Working Professional',
#  'Esha',
#  'LLS',
#  'LLEd',
#  'E.Tech',
#  'Doctor',
#  'N.Pharm',
#  'LCA',
#  'B B.Com',
#  'RCA',
#  'Mihir',
#  'Advait']

# %%
degree_mapping = {
    'B.Sc': 'BSc',
    'B.Pharm': 'BPharm',
    'M.Pharm': 'MPharm', # M.Pharm과 MPharm 통일
    'B.Arch': 'BArch',
    'M.Arch': 'MArch', # M.Arch와 MArch 통일
    'B.Ed': 'BEd',
    'M.Ed': 'MEd',
    'B.Tech': 'BTech', # B.Tech와 MTech 통일
    'M.Tech': 'MTech', # M.Tech와 MTech 통일
    'B.Com': 'BCom',
    'M.Com': 'MCom',
    'M.Business Analyst': 'MBA', # 직업명이지만 학위로 분류될 가능성이 있어 MBA로 일단 통일
    'MBBS': 'MBBS', # 이미 통일되어 있지만 명시
    'MD': 'MD', # 이미 통일되어 있지만 명시
    'PhD': 'PhD', # 이미 통일되어 있지만 명시
    'Class 12': 'HighSchool', # Class 12와 12th 통일
    'Class 11': 'HighSchool', # Class 10과 10th 통일
    'M_Tech' : 'MTech', # M_Tech와 MTech 통일
}

df_7['degree'] = df_7['degree'].replace(degree_mapping)

outliers = [
    'Bhopal', 'Kalyan', # 도시/지역명
    '20', '29', '0', '5.61', '5.56', '7.06', '8.56', '24', '5.88', 'B.03', 'B.3.79', # 숫자 (나이, CGPA 등)
    'Nalini', 'Veda', 'Nalini', 'Vrinda', 'Bhavesh', 'Ritik', 'Brithika', 'Pihu', # 이름/사람
    'Jhanvi', 'Aarav', 'Lata', 'Navya', 'Mahika', 'Mthanya', 'Esha', 'Mihir', 'Advait', # 이름/사람    
    'Degree', 'CGPA', 'M', 'B', 'BB', 'ACA', 'HCA', 'LLS', 'RCA', # 컬럼명/기타 명칭
    'UX/UI Designer', 'Business Analyst', 'HR Manager', 'M. Business Analyst', 'Data Scientist', # 직업명 (Profession 컬럼에 있어야 할 값)
    'Plumber', 'Entrepreneur', 'Doctor', 'Working Professional', # 직업명 (Profession 컬럼에 있어야 할 값)
    'S.Tech', 'H_Pharm', 'P.Com', 'LL.Com', 'L.Ed', 'P.Pharm', 'S.Pharm', 'LLBA', # 알 수 없는 약어 또는 오타/불완전한 학위명
    'LLCom', 'BPA', 'LLTech', 'LHM', 'S.Arch', 'B.Student', 'LL B.Ed', 'M.S', # 알 수 없는 약어 또는 오타/불완전한 학위명
    'K.Ed', 'LLEd', 'E.Tech', 'N.Pharm', 'LCA', 'B BA', 'B.B.Arch', 'Unite', # 알 수 없는 약어 또는 오타/불완전한 학위명
    'Badhya', 'Vivaan', 'Brit', 'B B.Com','Marsh' # 알 수 없는 약어 또는 오타/불완전한 학위명
    ]

# degree 컬럼에서 NaN 처리
df_7['degree'] = df_7['degree'].replace(outliers, np.nan)

# %%
df_7['degree'] = df_7['degree'].fillna('Unknown') # NaN을 'Unknown'으로 대체

# %%
df_7['degree'].value_counts()
# Out:
# degree
# HighSchool    14719
# BEd           11689
# BArch          8742
# BCom           8108
# BPharm         5854
# BCA            5735
# MEd            5663
# MCA            5225
# BBA            5028
# BSc            5020
# MSc            4876
# LLM            4642
# MPharm         4535
# MTech          4473
# BTech          4424
# LLB            4344
# BHM            4305
# MBA            3812
# BA             3741
# ME             3626
# MD             3381
# MHM            3283
# BE             3099
# PhD            3099
# MCom           3091
# MBBS           3077
# MA             2886
# Unknown          94
# MArch             5
# MPA               1
# BH                1
# Name: count, dtype: int64

# %% [markdown]
# #### suicidal_thoughts

# %%
df_7['suicidal_thoughts'].value_counts()
df_7['suicidal_thoughts'] = df_7['suicidal_thoughts'].replace({'Yes': 1, 'No': 0})
df_7['suicidal_thoughts'].value_counts()
# Out:
# /var/folders/t3/2n0cthkn35z3g9p87_tw_5wm0000gn/T/ipykernel_1208/2323989350.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_7['suicidal_thoughts'] = df_7['suicidal_thoughts'].replace({'Yes': 1, 'No': 0})
# suicidal_thoughts
# 0    71085
# 1    69493
# Name: count, dtype: int64

# %% [markdown]
# #### family history

# %%
df_7['family_mh_history'].value_counts()
df_7['family_mh_history'] = df_7['family_mh_history'].replace({'Yes': 1, 'No': 0})
df_7['family_mh_history'].value_counts()
# Out:
# /var/folders/t3/2n0cthkn35z3g9p87_tw_5wm0000gn/T/ipykernel_1208/3887206341.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_7['family_mh_history'] = df_7['family_mh_history'].replace({'Yes': 1, 'No': 0})
# family_mh_history
# 0    70688
# 1    69890
# Name: count, dtype: int64

# %% [markdown]
# #### work_study_hours

# %%
df_7['work_study_hours'].value_counts()
# Out:
# work_study_hours
# 10.0    14188
# 11.0    12821
# 9.0     12701
# 0.0     12059
# 12.0    11398
# 2.0     10588
# 6.0     10420
# 7.0      9867
# 1.0      9793
# 3.0      9463
# 5.0      9329
# 4.0      9053
# 8.0      8898
# Name: count, dtype: int64

# %% [markdown]
# #### financial_stress

# %%
df_7['financial_stress'].isna().sum() # 4
df_7[df_7['financial_stress'].isna()]
# Out:
#           id    name  gender   age age_group       city  profession  cgpa  \
# 22377  22377   Manvi       1  32.0     26-35   Varanasi     student  5.64
# 51485  51485  Ishwar       0  37.0     36-45  Hyderabad  unemployed  0.00
# 68910  68910    Arav       0  29.0     26-35  Hyderabad     student  8.94
# 97610  97610    Pari       1  20.0     18-25    Kolkata     student  6.83
#
#            degree  work_study_pressure  work_study_satisfaction  \
# 22377         BCA                  3.0                      1.0
# 51485  HighSchool                  4.0                      2.0
# 68910         BEd                  2.0                      3.0
# 97610        MBBS                  1.0                      1.0
#
#        financial_stress sleep_duration dietary_habits  work_study_hours  \
# 22377               NaN   insufficient        Healthy              12.0
# 51485               NaN      excessive       Moderate               9.0
# 68910               NaN   insufficient      Unhealthy              12.0
# 97610               NaN   insufficient        Healthy               9.0
#
#        family_mh_history  suicidal_thoughts  depression
# 22377                  0                  0           1
# 51485                  0                  1           0
# 68910                  1                  0           0
# 97610                  1                  0           0

# %%
df_7.groupby('profession')['financial_stress'].mean().loc[['student', 'unemployed']] # 0.0
# Out:
# profession
# student       3.140001
# unemployed    3.127616
# Name: financial_stress, dtype: float64

# %%
df_7.loc[
    (df_7['profession'] == 'student') & (df_7['financial_stress'].isna()),
    'financial_stress'
] = df_7.groupby('profession')['financial_stress'].mean().loc['student']
df_7[(df_7['profession'] == 'student') & (df_7['financial_stress'].isna())] # NaN 처리 완료

df_7.loc[
    (df_7['profession'] == 'unemployed') & (df_7['financial_stress'].isna()),
    'financial_stress'
] = df_7.groupby('profession')['financial_stress'].mean().loc['unemployed']
df_7[(df_7['profession'] == 'unemployed') & (df_7['financial_stress'].isna())] # NaN 처리 완료
# financial_stress NaN 처리 완료
df_7['financial_stress'].isna().sum() # 0 확인
# Out:
# 0

# %% [markdown]
# #### City

# %%
df_7['city'].unique()
# Out:
# array(['Ludhiana', 'Varanasi', 'Visakhapatnam', 'Mumbai', 'Kanpur',
#        'Ahmedabad', 'Thane', 'Nashik', 'Bangalore', 'Patna', 'Rajkot',
#        'Jaipur', 'Pune', 'Lucknow', 'Meerut', 'Agra', 'Surat',
#        'Faridabad', 'Hyderabad', 'Srinagar', 'Ghaziabad', 'Kolkata',
#        'Chennai', 'Kalyan', 'Nagpur', 'Vadodara', 'Vasai-Virar', 'Delhi',
#        'Bhopal', 'Indore', 'Ishanabad', 'Vidhi', 'Ayush', 'Gurgaon',
#        'Krishna', 'Aishwarya', 'Keshav', 'Harsha', 'Nalini', 'Aditya',
#        'Malyansh', 'Raghavendra', 'Saanvi', 'M.Tech', 'Bhavna',
#        'Less Delhi', 'Nandini', 'M.Com', 'Plata', 'Atharv', 'Pratyush',
#        'City', '3.0', 'Less than 5 Kalyan', 'MCA', 'Mira', 'Moreadhyay',
#        'Morena', 'Ishkarsh', 'Kashk', 'Mihir', 'Vidya', 'Tolkata', 'Anvi',
#        'Krinda', 'Ayansh', 'Shrey', 'Ivaan', 'Vaanya', 'Gaurav', 'Harsh',
#        'Reyansh', 'Kashish', 'Kibara', 'Vaishnavi', 'Chhavi', 'Parth',
#        'Mahi', 'Tushar', 'MSc', 'No', 'Rashi', 'ME', 'Molkata',
#        'Researcher', 'Kagan', 'Armaan', 'Ithal', 'Nalyan', 'Dhruv',
#        'Galesabad', 'Itheg', 'Aaradhya', 'Pooja', 'Khushi', 'Khaziabad',
#        'Jhanvi', 'Unirar'], dtype=object)

# %%
a = df_7['city'].value_counts().sort_values(ascending=True)
a[a<7].index.tolist()
# Out:
# ['Unirar',
#  'Parth',
#  'Kashish',
#  'Kibara',
#  'Chhavi',
#  'Vaishnavi',
#  'Tushar',
#  'MSc',
#  'Ivaan',
#  'Vaanya',
#  'Gaurav',
#  'Harsh',
#  'Reyansh',
#  'Ishanabad',
#  'Vidhi',
#  'Shrey',
#  'Moreadhyay',
#  'Morena',
#  'Kashk',
#  'Ishkarsh',
#  'Anvi',
#  'Krinda',
#  'Ayansh',
#  'Tolkata',
#  'Mira',
#  'Less than 5 Kalyan',
#  '3.0',
#  'Gurgaon',
#  'Aishwarya',
#  'Krishna',
#  'Aditya',
#  'Galesabad',
#  'Itheg',
#  'Khaziabad',
#  'Malyansh',
#  'Raghavendra',
#  'M.Tech',
#  'Aaradhya',
#  'Dhruv',
#  'Nalyan',
#  'Khushi',
#  'Kagan',
#  'Researcher',
#  'ME',
#  'Rashi',
#  'Less Delhi',
#  'Plata',
#  'Pooja',
#  'Ithal',
#  'No',
#  'Jhanvi',
#  'Armaan',
#  'Nalini',
#  'Keshav',
#  'Molkata',
#  'Atharv',
#  'Ayush',
#  'MCA',
#  'M.Com',
#  'City',
#  'Harsha',
#  'Vidya',
#  'Pratyush',
#  'Saanvi',
#  'Mahi',
#  'Bhavna',
#  'Nandini']

# %%
urban = ['Mumbai','Delhi','Bangalore','Hyderabad','Chennai','Ahmedabad'] # ,'Pune'
rural = ['Srinagar','Varanasi','Rajkot','Agra','Meerut']  #,'Ludhiana','Visakhapatnam'
total = urban + rural


a = df_7[df['city'].isin(urban)].shape[0]; b = df_7[df_7['city'].isin(rural)].shape[0]
print(a, b)
print(a/(b + a) * 100)
print(b/(b + a) * 100)
print(b-a)
# Out:
# 26808 25072
# 51.673091750192754
# 48.326908249807246
# -1736
# /var/folders/t3/2n0cthkn35z3g9p87_tw_5wm0000gn/T/ipykernel_1208/2632073379.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   a = df_7[df['city'].isin(urban)].shape[0]; b = df_7[df_7['city'].isin(rural)].shape[0]

# %%
df_8 = df_7.copy()
df_8['urban_rural'] = df_8['city'].apply(lambda x: 'urban' if x in urban else ('rural' if x in rural else 'other'))

# %%
df_final = df_8[df_8['urban_rural'] != 'other']
df_final.info() # 최종 데이터셋 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51880 entries, 1 to 140698
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       51880 non-null  int64
#  1   name                     51880 non-null  object
#  2   gender                   51880 non-null  int64
#  3   age                      51880 non-null  float64
#  4   age_group                51880 non-null  category
#  5   city                     51880 non-null  object
#  6   profession               51880 non-null  object
#  7   cgpa                     51880 non-null  float64
#  8   degree                   51880 non-null  object
#  9   work_study_pressure      51880 non-null  float64
#  10  work_study_satisfaction  51880 non-null  float64
#  11  financial_stress         51880 non-null  float64
#  12  sleep_duration           51880 non-null  object
#  13  dietary_habits           51880 non-null  object
#  14  work_study_hours         51880 non-null  float64
#  15  family_mh_history        51880 non-null  int64
#  16  suicidal_thoughts        51880 non-null  int64
#  17  depression               51880 non-null  int64
#  18  urban_rural              51880 non-null  object
# dtypes: category(1), float64(6), int64(5), object(7)
# memory usage: 7.6+ MB

# %%
df_final.to_csv(os.path.join(PATH, 'df_final.csv'), index=False)

# %%
df_8.to_csv(os.path.join(PATH, 'df_cleaned.csv'), index=False)
